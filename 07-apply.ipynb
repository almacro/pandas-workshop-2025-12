# %%
def my_function():
    pass

# %%
def my_sq(x):
    return x ** 2

# %%
my_sq(16)
# Out:
# 256

# %%
my_sq("hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 my_sq("hello")
#
# Cell In[2], line 2, in my_sq(x)
#       1 def my_sq(x):
# ----> 2     return x ** 2
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
assert my_sq(4) == 16

# %%
type(4)
# Out:
# int

# %%
def my_sq(x: int|float) -> int|float:
    return x ** 2

# %%
import pandas as pd

# %%
df = pd.DataFrame({ "a": [10, 20, 30], "b": [20, 30, 40] })

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
df["a"] ** 2
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
df.a ** 2
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
my_sq(df.a)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
type(df.a)
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       3 non-null      int64
#  1   b       3 non-null      int64
# dtypes: int64(2)
# memory usage: 180.0 bytes

# %%
df.a.apply(my_sq)
# Out:
# 0    100
# 1    400
# 2    900
# Name: a, dtype: int64

# %%
my_sq
# Out:
# <function __main__.my_sq(x: int | float) -> int | float>

# %%
def my_exp(x, e):
    return x ** e

# %%
my_exp(4, 2)
# Out:
# 16

# %%
my_exp(2, 10)
# Out:
# 1024

# %%
df.a.apply(my_exp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.a.apply(my_exp)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
#    4757         by_row=by_row,
#    4758         args=args,
#    4759         kwargs=kwargs,
# -> 4760     ).apply()
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\apply.py:1207, in SeriesApply.apply(self)
#    1204     return self.apply_compat()
#    1206 # self.func is Callable
# -> 1207 return self.apply_standard()
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\apply.py:1287, in SeriesApply.apply_standard(self)
#    1281 # row-wise access
#    1282 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1283 # we need to give `na_action="ignore"` for categorical data.
#    1284 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1285 #  Categorical (GH51645).
#    1286 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1287 mapped = obj._map_values(
#    1288     mapper=curried, na_action=action, convert=self.convert_dtype
#    1289 )
#    1291 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1292     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1293     #  See also GH#25959 regarding EA support
#    1294     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\algorithms.py:1814, in map_array(arr, mapper, na_action, convert)
#    1812 values = arr.astype(object, copy=False)
#    1813 if na_action is None:
# -> 1814     return lib.map_infer(values, mapper, convert=convert)
#    1815 else:
#    1816     return lib.map_infer_mask(
#    1817         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1818     )
#
# File lib.pyx:2917, in pandas._libs.lib.map_infer()
#
# TypeError: my_exp() missing 1 required positional argument: 'e'

# %%
df.a.apply(my_exp, e=10)
# Out:
# 0        10000000000
# 1     10240000000000
# 2    590490000000000
# Name: a, dtype: int64

# %%
def my_exp_flipped(e, x):
    return my_exp(x, e)

# %%
df.a.apply(my_exp_flipped, x=2)
# Out:
# 0          1024
# 1       1048576
# 2    1073741824
# Name: a, dtype: int64

# %%
df.a.apply(lambda val: my_exp(2, val))
# Out:
# 0          1024
# 1       1048576
# 2    1073741824
# Name: a, dtype: int64

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
def print_me(x):
    print(x)

# %%
x = print_me("hello")
# Out:
# hello

# %%
x

# %%
df.a.apply(print_me)
# Out:
# 10
# 20
# 30
# 0    None
# 1    None
# 2    None
# Name: a, dtype: object

# %%
df.apply(print_me)
# Out:
# 0    10
# 1    20
# 2    30
# Name: a, dtype: int64
# 0    20
# 1    30
# 2    40
# Name: b, dtype: int64
# a    None
# b    None
# dtype: object

# %%
def avg_3(x, y, z):
    return (x + y + z) / 3

# %%
sum(df.a + df.b)
# Out:
# 150

# %%
assert avg_3(0,1,2) == 1

# %%
df.apply(avg_3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.apply(avg_3)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\frame.py:10037, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, **kwargs)
#   10025 from pandas.core.apply import frame_apply
#   10027 op = frame_apply(
#   10028     self,
#   10029     func=func,
#    (...)
#   10035     kwargs=kwargs,
#   10036 )
# > 10037 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\apply.py:837, in FrameApply.apply(self)
#     834 elif self.raw:
#     835     return self.apply_raw()
# --> 837 return self.apply_standard()
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\apply.py:963, in FrameApply.apply_standard(self)
#     962 def apply_standard(self):
# --> 963     results, res_index = self.apply_series_generator()
#     965     # wrap results
#     966     return self.wrap_results(results, res_index)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\apply.py:979, in FrameApply.apply_series_generator(self)
#     976 with option_context("mode.chained_assignment", None):
#     977     for i, v in enumerate(series_gen):
#     978         # ignore SettingWithCopy here in case the user mutates
# --> 979         results[i] = self.func(v, *self.args, **self.kwargs)
#     980         if isinstance(results[i], ABCSeries):
#     981             # If we have a view on v, we need to make a copy because
#     982             #  series_generator will swap out the underlying data
#     983             results[i] = results[i].copy(deep=False)
#
# TypeError: avg_3() missing 2 required positional arguments: 'y' and 'z'

# %%
avg_3(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 avg_3(10)
#
# TypeError: avg_3() missing 2 required positional arguments: 'y' and 'z'

# %%
def avg_3_apply(col):
    return col.mean()

# %%
df.apply(avg_3_apply)
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
def avg_3_apply(col):
    x = col[0]
    y = col[1]
    z = col[2]
    return (x + y + z)/3

# %%
df.apply(avg_3_apply)
# Out:
# a    20.0
# b    30.0
# dtype: float64

# %%
df.apply(print_me, axis='columns')
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# a    20
# b    30
# Name: 1, dtype: int64
# a    30
# b    40
# Name: 2, dtype: int64
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
df.apply(print_me, axis=1)
# Out:
# a    10
# b    20
# Name: 0, dtype: int64
# a    20
# b    30
# Name: 1, dtype: int64
# a    30
# b    40
# Name: 2, dtype: int64
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
df.a + df.b
# Out:
# 0    30
# 1    50
# 2    70
# dtype: int64

# %%
(df.a + df.b)/2
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
def avg_2(x, y):
    return (x + y) / 2

# %%
avg_2(df.a, df.b)
# Out:
# 0    15.0
# 1    25.0
# 2    35.0
# dtype: float64

# %%
import numpy as np

def avg_2_mod(x, y):
    if (x == 20):
        return np.nan
    else:
        return (x + y) / 2

# %%
avg_2_mod(20, 10)
# Out:
# nan

# %%
avg_2_mod(0, 10)
# Out:
# 5.0

# %%
assert avg_2_mod(0, 10) == 5

# %%
avg_2_mod(df.a, df.b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2708\68208767.py in ?()
# ----> 1 avg_2_mod(df.a, df.b)
#
# ~\AppData\Local\Temp\ipykernel_2708\323172123.py in ?(x, y)
#       3 def avg_2_mod(x, y):
# ----> 4     if (x == 20):
#       5         return np.nan
#       6     else:
#       7         return (x + y) / 2
#
# ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df.a == 20
# Out:
# 0    False
# 1     True
# 2    False
# Name: a, dtype: bool

# %%
(df.a == 20).any()
# Out:
# True

# %%
(df.a == 20).all()
# Out:
# False

# %%
avg_2_mod_np = np.vectorize(avg_2_mod)

# %%
avg_2_mod_np(df.a, df.b)
# Out:
# array([15., nan, 35.])

# %%
df
# Out:
#     a   b
# 0  10  20
# 1  20  30
# 2  30  40

# %%
@np.vectorize
def avg_2_mod(x, y):
    if (x == 20):
        return np.nan
    else:
        return (x + y) / 2

# %%
avg_2_mod(df.a, df.b)
# Out:
# array([15., nan, 35.])

# %%
import numba

# %%
@numba.vectorize
def avg_2_mod_numba(x, y):
    if (x == 20):
        return np.nan
    else:
        return (x + y) / 2

# %%
avg_2_mod_numba(10, 20)
# Out:
# 15.0

# %%
avg_2_mod_numba(0, 10)
# Out:
# 5.0

# %%
avg_2_mod_numba(df.a, df.b)
# Out:
# 0    15.0
# 1     NaN
# 2    35.0
# dtype: float64

# %%
# %%timeit
avg_2(df.a, df.b)
# Out:
# 156 µs ± 6.03 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
(df.a + df.b) / 2
# Out:
# 145 µs ± 4.61 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
avg_2_mod_np(df.a, df.b)
# Out:
# 46.2 µs ± 2.9 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
avg_2_mod_numba(df.a, df.b)
# Out:
# 140 µs ± 9.99 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
avg_2_mod_numba(df.a.values, df.b.values)
# Out:
# 14.8 µs ± 836 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
