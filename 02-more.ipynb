# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.1'

# %%
scientists = pd.read_csv("data/scientists.csv")

# %%
scientists
# Out:
#                    Name        Born        Died  Age          Occupation
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician

# %%
ages = scientists.Age

# %%
ages
# Out:
# 0    37
# 1    61
# 2    90
# 3    66
# 4    56
# 5    45
# 6    41
# 7    77
# Name: Age, dtype: int64

# %%
ages.mean()
# Out:
# 59.125

# %%
ages > ages.mean()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# Name: Age, dtype: bool

# %%
ages[ages > ages.mean()]
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
ages.loc[ages > ages.mean()]
# Out:
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %%
scientists.loc[ages > ages.mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
ages.loc[ages > ages.mean() and ages > 75]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24928\2476184145.py in ?()
# ----> 1 ages.loc[ages > ages.mean() and ages > 75]
#
# ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1517     @final
#    1518     def __nonzero__(self) -> NoReturn:
# -> 1519         raise ValueError(
#    1520             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1521             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1522         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
ages.loc[ages > ages.mean() & ages > 75]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\ops\array_ops.py:364, in na_logical_op(x, y, op)
#     355 try:
#     356     # For exposition, write:
#     357     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     362     # Then Cases where this goes through without raising include:
#     363     #  (xint or xbool) and (yint or bool)
# --> 364     result = op(x, y)
#     365 except TypeError:
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\ops\array_ops.py:378, in na_logical_op(x, y, op)
#     377 try:
# --> 378     result = libops.scalar_binop(x, y, op)
#     379 except (
#     380     TypeError,
#     381     ValueError,
#    (...)
#     384     NotImplementedError,
#     385 ) as err:
#
# File ops.pyx:180, in pandas._libs.ops.scalar_binop()
#
# ValueError: Buffer dtype mismatch, expected 'Python object' but got 'long long'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ages.loc[ages > ages.mean() & ages > 75]
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\generic.py:2102, in NDFrame.__array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    2098 @final
#    2099 def __array_ufunc__(
#    2100     self, ufunc: np.ufunc, method: str, *inputs: Any, **kwargs: Any
#    2101 ):
# -> 2102     return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\arraylike.py:273, in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     270 kwargs = _standardize_out_kwarg(**kwargs)
#     272 # for binary ops, use our custom dunder methods
# --> 273 result = maybe_dispatch_ufunc_to_dunder_op(self, ufunc, method, *inputs, **kwargs)
#     274 if result is not NotImplemented:
#     275     return result
#
# File ops_dispatch.pyx:113, in pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op()
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\arraylike.py:74, in OpsMixin.__rand__(self, other)
#      72 @unpack_zerodim_and_defer("__rand__")
#      73 def __rand__(self, other):
# ---> 74     return self._logical_method(other, roperator.rand_)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\series.py:5810, in Series._logical_method(self, other, op)
#    5807 lvalues = self._values
#    5808 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5810 res_values = ops.logical_op(lvalues, rvalues, op)
#    5811 return self._construct_result(res_values, name=res_name)
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\ops\array_ops.py:456, in logical_op(left, right, op)
#     452 else:
#     453     # i.e. scalar
#     454     is_other_int_dtype = lib.is_integer(rvalues)
# --> 456 res_values = na_logical_op(lvalues, rvalues, op)
#     458 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     459 #   integer dtypes.  Otherwise these are boolean ops
#     460 if not (left.dtype.kind in "iu" and is_other_int_dtype):
#
# File ~\anaconda3\envs\py311class\Lib\site-packages\pandas\core\ops\array_ops.py:387, in na_logical_op(x, y, op)
#     379         except (
#     380             TypeError,
#     381             ValueError,
#    (...)
#     384             NotImplementedError,
#     385         ) as err:
#     386             typ = type(y).__name__
# --> 387             raise TypeError(
#     388                 f"Cannot perform '{op.__name__}' with a dtyped [{x.dtype}] array "
#     389                 f"and scalar of type [{typ}]"
#     390             ) from err
#     392 return result.reshape(x.shape)
#
# TypeError: Cannot perform 'rand_' with a dtyped [int64] array and scalar of type [bool]

# %%
ages.loc[(ages > ages.mean()) & (ages > 75)]
# Out:
# 2    90
# 7    77
# Name: Age, dtype: int64

# %%
ages.loc[(ages > ages.mean()) & ~(ages > 75)]
# Out:
# 1    61
# 3    66
# Name: Age, dtype: int64

# %%
scientists.loc[scientists.Age > scientists["Age"].mean()]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
scientists.loc[scientists.Age > scientists["Age"].mean(), :]
# Out:
#                    Name        Born        Died  Age     Occupation
# 1        William Gosset  1876-06-13  1937-10-16   61   Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90          Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66        Chemist
# 7          Johann Gauss  1777-04-30  1855-02-23   77  Mathematician

# %%
scientists.loc[scientists.Age > scientists["Age"].mean(), ["Name", "Age"]]
# Out:
#                    Name  Age
# 1        William Gosset   61
# 2  Florence Nightingale   90
# 3           Marie Curie   66
# 7          Johann Gauss   77

# %%
scientists.loc[:, ["Name", "Age"]]
# Out:
#                    Name  Age
# 0     Rosaline Franklin   37
# 1        William Gosset   61
# 2  Florence Nightingale   90
# 3           Marie Curie   66
# 4         Rachel Carson   56
# 5             John Snow   45
# 6           Alan Turing   41
# 7          Johann Gauss   77

# %%
scientists.dtypes
# Out:
# Name          object
# Born          object
# Died          object
# Age            int64
# Occupation    object
# dtype: object

# %%
scientists.head(2)
# Out:
#                 Name        Born        Died  Age    Occupation
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician

# %%
pd.to_datetime(scientists["Born"])
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
pd.to_datetime(scientists["Born"], format="%Y-%m-%d")
# Out:
# 0   1920-07-25
# 1   1876-06-13
# 2   1820-05-12
# 3   1867-11-07
# 4   1907-05-27
# 5   1813-03-15
# 6   1912-06-23
# 7   1777-04-30
# Name: Born, dtype: datetime64[ns]

# %%
scientists["born_dt"] = pd.to_datetime(scientists["Born"], format="%Y-%m-%d")

# %%
scientists.head(2)
# Out:
#                 Name        Born        Died  Age    Occupation    born_dt
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13

# %%
scientists = scientists.assign(died_dt = pd.to_datetime(scientists["Died"], format="%Y-%m-%d"))

# %%
scientists.dtypes
# Out:
# Name                  object
# Born                  object
# Died                  object
# Age                    int64
# Occupation            object
# born_dt       datetime64[ns]
# died_dt       datetime64[ns]
# dtype: object

# %%
scientists.head(2)
# Out:
#                 Name        Born        Died  Age    Occupation    born_dt  \
# 0  Rosaline Franklin  1920-07-25  1958-04-16   37       Chemist 1920-07-25
# 1     William Gosset  1876-06-13  1937-10-16   61  Statistician 1876-06-13
#
#      died_dt
# 0 1958-04-16
# 1 1937-10-16

# %%
scientists.to_csv("data/scientists_clean.csv")

# %%
s = pd.read_csv("data/scientists_clean.csv")

# %%
s
# Out:
#    Unnamed: 0                  Name        Born        Died  Age  \
# 0           0     Rosaline Franklin  1920-07-25  1958-04-16   37
# 1           1        William Gosset  1876-06-13  1937-10-16   61
# 2           2  Florence Nightingale  1820-05-12  1910-08-13   90
# 3           3           Marie Curie  1867-11-07  1934-07-04   66
# 4           4         Rachel Carson  1907-05-27  1964-04-14   56
# 5           5             John Snow  1813-03-15  1858-06-16   45
# 6           6           Alan Turing  1912-06-23  1954-06-07   41
# 7           7          Johann Gauss  1777-04-30  1855-02-23   77
#
#            Occupation     born_dt     died_dt
# 0             Chemist  1920-07-25  1958-04-16
# 1        Statistician  1876-06-13  1937-10-16
# 2               Nurse  1820-05-12  1910-08-13
# 3             Chemist  1867-11-07  1934-07-04
# 4           Biologist  1907-05-27  1964-04-14
# 5           Physician  1813-03-15  1858-06-16
# 6  Computer Scientist  1912-06-23  1954-06-07
# 7       Mathematician  1777-04-30  1855-02-23

# %%
scientists.to_csv("data/scientists_clean.csv", index=False)

# %%
s = pd.read_csv("data/scientists_clean.csv")

# %%
s
# Out:
#                    Name        Born        Died  Age          Occupation  \
# 0     Rosaline Franklin  1920-07-25  1958-04-16   37             Chemist
# 1        William Gosset  1876-06-13  1937-10-16   61        Statistician
# 2  Florence Nightingale  1820-05-12  1910-08-13   90               Nurse
# 3           Marie Curie  1867-11-07  1934-07-04   66             Chemist
# 4         Rachel Carson  1907-05-27  1964-04-14   56           Biologist
# 5             John Snow  1813-03-15  1858-06-16   45           Physician
# 6           Alan Turing  1912-06-23  1954-06-07   41  Computer Scientist
# 7          Johann Gauss  1777-04-30  1855-02-23   77       Mathematician
#
#       born_dt     died_dt
# 0  1920-07-25  1958-04-16
# 1  1876-06-13  1937-10-16
# 2  1820-05-12  1910-08-13
# 3  1867-11-07  1934-07-04
# 4  1907-05-27  1964-04-14
# 5  1813-03-15  1858-06-16
# 6  1912-06-23  1954-06-07
# 7  1777-04-30  1855-02-23

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Born        8 non-null      object
#  2   Died        8 non-null      object
#  3   Age         8 non-null      int64
#  4   Occupation  8 non-null      object
#  5   born_dt     8 non-null      object
#  6   died_dt     8 non-null      object
# dtypes: int64(1), object(6)
# memory usage: 580.0+ bytes
