# %%
# random tips and tricks

# %%
123123123123123
# Out:
# 123123123123123

# %%
# improve readability with separators
123_123_123_123_123
# Out:
# 123123123123123

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
# trailing commas allowed; helps with adding more values later as needed
[1, 2, 3,]
# Out:
# [1, 2, 3]

# %%
[
    1,
    2,
    3
]
# Out:
# [1, 2, 3]

# %%
# vertical layout allows commenting value(s) during debug/test
[
    1,
    #2,
    3
]
# Out:
# [1, 3]

# %%
[
    1,
    2,
    #3
]
# Out:
# [1, 2]

# %%
# end list content with trailing comma as best practice
[
    1,
    2,
    3,
]
# Out:
# [1, 2, 3]
